-- %%
create table if not exists bakehouse.default.customers as select *, current_timestamp as ingest_ts, when case customerID is null or first_name is null, last_name is null then 1 else 0 end case as _error from samples.bakehouse.sales_customers;
